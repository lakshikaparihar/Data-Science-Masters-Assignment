# %%
import pandas as pd
course_name = ['Data Science', 'Machine Learning', 'Big Data', 'Data Engineer']
duration = [2,3,6,4]
df = pd.DataFrame(data = {'course_name' : course_name, 'duration' : duration})

# %%
df
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6
# 3     Data Engineer         4

# %% [markdown]
# ### 1. Write a code to print the data present in the second row of the dataframe, df.

# %%
df.iloc[[2]]
# Out:
#   course_name  duration
# 2    Big Data         6

# %% [markdown]
# <br>
# <br>
#
# ### 2. What is the difference between the functions loc and iloc in pandas.DataFrame?

# %% [raw]
# loc selects specific rows and columns according to the label wheras iloc selects specific rows and columns according to the index or in-built index defined by python.

# %%
# loc only works with the named value, if we give the integer index value of column like in the cell below ,
# than it will give error

df.loc[0:2,['course_name']]
# Out:
#         course_name
# 0      Data Science
# 1  Machine Learning
# 2          Big Data

# %%
# iloc only works with the integer value , if we give the column name like in the cell above , 
# than it will give error

df.iloc[0:2,[0]]
# Out:
#         course_name
# 0      Data Science
# 1  Machine Learning

# %% [markdown]
# <br>
# <br>
#
# ### 3. Reindex the given dataframe using a variable, reindex = [3,0,1,2] and store it in the variable, new_df then find the output for both new_df.loc[2] and new_df.iloc[2].
#
# Did you observe any difference in both the outputs? If so then explain it.

# %%
reindex = [3,0,1,2]
new_df = df.reindex(reindex)
new_df
# Out:
#         course_name  duration
# 3     Data Engineer         4
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6

# %%
new_df.loc[2]
# Out:
# course_name    Big Data
# duration              6
# Name: 2, dtype: object

# %%
new_df.iloc[2]
# Out:
# course_name    Machine Learning
# duration                      3
# Name: 1, dtype: object

# %% [raw]
# As loc selects the rows by the label thats why it gave the output Big Data whereas iloc selects the rows by the inbuilt-index thats why it gave the output Machine Learning

# %% [markdown]
# <br>
# ===========================X==============================
# <br>

# %%
import pandas as pd
import numpy as np
columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
indices = [1,2,3,4,5,6]
#Creating a dataframe:
df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.181395  0.145281  0.346784  0.143027  0.466506  0.672859
# 2  0.631509  0.549203  0.124511  0.062685  0.383624  0.064411
# 3  0.918240  0.614379  0.163841  0.178103  0.856667  0.769649
# 4  0.358453  0.190470  0.155382  0.277731  0.859332  0.389143
# 5  0.471770  0.903437  0.738002  0.644896  0.273108  0.027499
# 6  0.612183  0.747659  0.588230  0.092918  0.129944  0.921434

# %% [markdown]
# <br>
# <br>
#
# ### 4. Write a code to find the following statistical measurements for the above dataframe df1:

# %% [raw]
# (i) mean of each and every column present in the dataframe.

# %%
df1.mean()
# Out:
# column_1    0.528925
# column_2    0.525072
# column_3    0.352792
# column_4    0.233227
# column_5    0.494864
# column_6    0.474166
# dtype: float64

# %% [raw]
# (ii) standard deviation of column, ‘column_2’

# %%
df1['column_2'].std()
# Out:
# 0.30247744515647057

# %% [markdown]
# <br>
# <br>
#
# ### 5. Replace the data present in the second row of column, ‘column_2’ by a string variable then find the mean of column, column_2.
#
# If you are getting errors in executing it then explain why.
# [Hint: To replace the data use df1.loc[] and equate this to string data of your choice.]

# %%
df1.loc[2,['column_2']] = "data"
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.181395  0.145281  0.346784  0.143027  0.466506  0.672859
# 2  0.631509      data  0.124511  0.062685  0.383624  0.064411
# 3  0.918240  0.614379  0.163841  0.178103  0.856667  0.769649
# 4  0.358453   0.19047  0.155382  0.277731  0.859332  0.389143
# 5  0.471770  0.903437  0.738002  0.644896  0.273108  0.027499
# 6  0.612183  0.747659  0.588230  0.092918  0.129944  0.921434

# %%
df1['column_2'].mean()

# %% [raw]
# Getting error in calculating mean because one of the data in the column is a string and we can't calculate mean on string object.

# %% [markdown]
# <br>
# <br>
#
# ### 6. What do you understand about the windows function in pandas and list the types of windows functions?

# %% [raw]
# Window function are those which works under a particular span or on a selected no. of rows at a time. Types of windows function are:

# %% [raw]
# Rolling window : These functions apply a calculation to a sliding window of data. The window is defined by a fixed number of rows or time periods.
#
# Example rolling(window_size) : Can be used in calculating the moving average , In the below example we have given the window size 3 , so it takes the last 3 element from a current row and find its mean

# %%
df1['moving_average'] = df1['column_1'].rolling(3).mean()
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6  moving_average
# 1  0.181395  0.145281  0.346784  0.143027  0.466506  0.672859             NaN
# 2  0.631509      data  0.124511  0.062685  0.383624  0.064411             NaN
# 3  0.918240  0.614379  0.163841  0.178103  0.856667  0.769649        0.577048
# 4  0.358453   0.19047  0.155382  0.277731  0.859332  0.389143        0.636068
# 5  0.471770  0.903437  0.738002  0.644896  0.273108  0.027499        0.582821
# 6  0.612183  0.747659  0.588230  0.092918  0.129944  0.921434        0.480802

# %% [raw]
# Expanding window : These functions apply a calculation to an expanding window of data. The window starts at the beginning of the data and grows with each row.
#
# Example cumsum() : use to calculate the cummulative sum , In the below example we don't need to explicity specify the window , it takes the cumulative sum from last row and add it with the current and it goes on

# %%
df1['cumulative_sum'] = df1['column_1'].cumsum()
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6  moving_average  \
# 1  0.181395  0.145281  0.346784  0.143027  0.466506  0.672859             NaN
# 2  0.631509      data  0.124511  0.062685  0.383624  0.064411             NaN
# 3  0.918240  0.614379  0.163841  0.178103  0.856667  0.769649        0.577048
# 4  0.358453   0.19047  0.155382  0.277731  0.859332  0.389143        0.636068
# 5  0.471770  0.903437  0.738002  0.644896  0.273108  0.027499        0.582821
# 6  0.612183  0.747659  0.588230  0.092918  0.129944  0.921434        0.480802
#
#    cumulative_sum
# 1        0.181395
# 2        0.812903
# 3        1.731144
# 4        2.089597
# 5        2.561367
# 6        3.173550

# %% [raw]
# Exponentially weighted moving average (EWMA) functions: These functions apply a weighted average to a sliding window of data. The weights are exponentially decreasing over time, with more recent data given a higher weight.
#
# Example : ewm().std() : use to calculate the standard deviation according to a window span

# %%
df1['standard_deviation'] = df1['column_1'].ewm(span=2).std()
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6  moving_average  \
# 1  0.181395  0.145281  0.346784  0.143027  0.466506  0.672859             NaN
# 2  0.631509      data  0.124511  0.062685  0.383624  0.064411             NaN
# 3  0.918240  0.614379  0.163841  0.178103  0.856667  0.769649        0.577048
# 4  0.358453   0.19047  0.155382  0.277731  0.859332  0.389143        0.636068
# 5  0.471770  0.903437  0.738002  0.644896  0.273108  0.027499        0.582821
# 6  0.612183  0.747659  0.588230  0.092918  0.129944  0.921434        0.480802
#
#    cumulative_sum  standard_deviation
# 1        0.181395                 NaN
# 2        0.812903            0.318279
# 3        1.731144            0.314481
# 4        2.089597            0.341089
# 5        2.561367            0.195393
# 6        3.173550            0.142304

# %% [raw]
# Grouped window functions: These functions apply a calculation to each group of data within a larger dataset. The groups can be defined by one or more columns in the data.
#
# Example : groupby.mean() : use to calculate the mean according to specific group

# %%
df1['column_7'] = [1,2,1,2,3,1]
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6  moving_average  \
# 1  0.181395  0.145281  0.346784  0.143027  0.466506  0.672859             NaN
# 2  0.631509      data  0.124511  0.062685  0.383624  0.064411             NaN
# 3  0.918240  0.614379  0.163841  0.178103  0.856667  0.769649        0.577048
# 4  0.358453   0.19047  0.155382  0.277731  0.859332  0.389143        0.636068
# 5  0.471770  0.903437  0.738002  0.644896  0.273108  0.027499        0.582821
# 6  0.612183  0.747659  0.588230  0.092918  0.129944  0.921434        0.480802
#
#    cumulative_sum  standard_deviation                        groupby_sum  \
# 1        0.181395                 NaN  (0.18139460336938507, [column_1])
# 2        0.812903            0.318279  (0.35845338032994356, [column_1])
# 3        1.731144            0.314481  (0.47176992189024824, [column_1])
# 4        2.089597            0.341089   (0.6121828932743978, [column_1])
# ...

# %%
groupby_sum = df1.groupby('column_7').agg({'column_1' : sum})
pd.merge(df1,groupby_sum,how="left",on="column_7")
# Out:
#    column_1_x  column_2  column_3  column_4  column_5  column_6  \
# 0    0.181395  0.145281  0.346784  0.143027  0.466506  0.672859
# 1    0.631509      data  0.124511  0.062685  0.383624  0.064411
# 2    0.918240  0.614379  0.163841  0.178103  0.856667  0.769649
# 3    0.358453   0.19047  0.155382  0.277731  0.859332  0.389143
# 4    0.471770  0.903437  0.738002  0.644896  0.273108  0.027499
# 5    0.612183  0.747659  0.588230  0.092918  0.129944  0.921434
#
#    moving_average  cumulative_sum  standard_deviation  \
# 0             NaN        0.181395                 NaN
# 1             NaN        0.812903            0.318279
# 2        0.577048        1.731144            0.314481
# 3        0.636068        2.089597            0.341089
# 4        0.582821        2.561367            0.195393
# 5        0.480802        3.173550            0.142304
#
#                          groupby_sum  column_7  column_1_y
# 0  (0.18139460336938507, [column_1])         1    1.711818
# ...

# %% [markdown]
# <br>
# <br>
#
# ### 7. Write a code to print only the current month and year at the time of answering this question.

# %%
date = pd.to_datetime('today')

print("Year : ",date.year)
print("Month : ",date.month_name())
# Out:
# Year :  2023
# Month :  February

# %% [markdown]
# <br>
# <br>
#
# ### 8. Write a Python program that takes in two dates as input (in the format YYYY-MM-DD) and calculates the difference between them in days, hours, and minutes using Pandas time delta. The program should prompt the user to enter the dates and display the result.

# %%
date1 = pd.to_datetime(input("Enter the First Date "))
date2 = pd.to_datetime(input("Enter the Second Date "))

print(pd.Timedelta(date1-date2))
# Out:
# Enter the First Date  2023-02-15
# Enter the Second Date  2023-01-14
# 32 days 00:00:00

# %% [markdown]
# <br>
# <br>
#
# ### 9. Write a Python program that reads a CSV file containing categorical data and converts a specified column to a categorical data type. The program should prompt the user to enter the file path, column name, and category order, and then display the sorted data.

# %%
dataF = pd.read_csv(input("Enter the file path : "))
col_name = input("Enter the column name : ")
category_order = input("Enter the category order separated by comma : ").split(',')
dataF
# Out:
# Enter the file path :  student-data.csv
# Enter the column name :  Gender
# Enter the category order separated by comma :  M,F
#    Student_ID  Test_Score      Name Gender
# 0           1          85  Lakshika      F
# 1           2          90     Kittu      M
# 2           3          80     Lippi      F
# 3           4          75     Mansi      F
# 4           5          85    Agatha      F
# 5           6          82      Nabh      M
# 6           7          78   Nilaksh      M
# 7           8          85     Gagan      M
# 8           9          90    Tushar      M
# 9          10          85    Pulkit      M

# %%
dataF[col_name] = pd.Categorical(dataF[col_name],categories=category_order,ordered=True)

# %%
data.sort_values(column_name)
# Out:
#    Student_ID  Test_Score      Name Gender
# 1           2          90     Kittu      M
# 5           6          82      Nabh      M
# 6           7          78   Nilaksh      M
# 7           8          85     Gagan      M
# 8           9          90    Tushar      M
# 9          10          85    Pulkit      M
# 0           1          85  Lakshika      F
# 2           3          80     Lippi      F
# 3           4          75     Mansi      F
# 4           5          85    Agatha      F

# %% [markdown]
# <br>
# <br>
#
# ### 10. Write a Python program that reads a CSV file containing sales data for different products and visualizes the data using a stacked bar chart to show the sales of each product category over time. The program should prompt the user to enter the file path and display the chart.

# %%
salesF = pd.read_csv(input("Enter the file path : "))
salesF
# Out:
# Enter the file path :  sales.csv
#     product  sales
# 0       Pen     20
# 1    Pencil     30
# 2  Notebook     70
# 3     Book      10

# %%
salesF.plot.bar(x='product',y='sales')
# Out:
# <AxesSubplot: xlabel='product'>

# %% [markdown]
# <br>
# <br>
#
# ### 11. You are given a CSV file containing student data that includes the student ID and their test score. Write a Python program that reads the CSV file, calculates the mean, median, and mode of the test scores, and displays the results in a table. The program should do the following
#
# * Prompt the user to enter the file path of the CSV file containing the student data.
# * Read the CSV file into a Pandas DataFrame.
# * Calculate the mean, median, and mode of the test scores using Pandas tools.
# * Display the mean, median, and mode in a table.

# %%
studentF = pd.read_csv(input("Enter the file path : "))
studentF
# Out:
# Enter the file path :  student_data.csv
#    Student ID  Test Score
# 0           1          85
# 1           2          90
# 2           3          80
# 3           4          75
# 4           5          85
# 5           6          82
# 6           7          78
# 7           8          85
# 8           9          90
# 9          10          85

# %%
mean = studentF['Test Score'].mean()
median = studentF['Test Score'].median()
mode = studentF['Test Score'].mode()

# %%
pd.DataFrame({"Statistic":['mean','median','mode'],"Value":[mean,median,mode[0]]})
# Out:
#   Statistic  Value
# 0      mean   83.5
# 1    median   85.0
# 2      mode   85.0
